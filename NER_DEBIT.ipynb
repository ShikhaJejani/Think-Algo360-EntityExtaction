# %%
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
import json
import io
from spacy.util import minibatch, compounding
import pandas as pd
import re

# %%
LABELS = ['DEBIT AMOUNT', 'DATE OF TRANSACTION', 'TIME OF TRANSACTION', 'REFERENCE NO', 'ACCOUNT NO', 'TOTAL BALANCE', 'CARD NO', 'LEDGER BALANCE', 'AVAILABLE CREDIT LIMIT', 'BENEFICIARY NAME',
          'COMBINED BALANCE', 'CHEQUE NO', 'CLEARING BALANCE', 'VENDOR LIST', 'ACCOUNT BALANCE', 'TOTAL CREDIT LIMIT', 'TXN INSTRUMENT', 'BENEFICIARY ACCOUNT', 'CURRENT OUTSTANDING']

with io.open('C:\\Users\\Simrandeep\\Desktop\\train_debit.json', encoding='utf8') as f:
    TRAIN_DATA = json.load(f)

# %%
@plac.annotations(
    model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
    new_model_name=("New model name for model meta.", "option", "nm", str),
    output_dir=("Optional output directory", "option", "o", Path),
    n_iter=("Number of training iterations", "option", "n", int))

def main(model=None, new_model_name='model', output_dir='C:\\Users\\Simrandeep\\Desktop\\Think\\ner output\\debit', n_iter=50):
    """Set up the pipeline and entity recognizer, and train the new entity."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank('en')  # create blank Language class
        print("Created blank 'en' model")

    # Add entity recognizer to model if it's not in the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner)
    # otherwise, get it, so we can add labels to it
    else:
        ner = nlp.get_pipe('ner')
    
    for label in LABELS:
        ner.add_label(label)   # add new entity label to entity recognizer

    # get names of other pipes to disable them during training
    random.seed(7)
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(texts, annotations, sgd=optimizer, drop=0.35,
                           losses=losses)
            print(losses)

    # test the trained model
    test_text = 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 1444.0 ON DATE 2018-05-19 04:20:21 PM BY UPI REF NO 813916610352.'
    doc = nlp(test_text)
    print("Entities in '%s'" % test_text)
    for ent in doc.ents:
        print(ent.label_, ent.text)

    # save model to output directory
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.meta['name'] = new_model_name  # rename model
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        doc2 = nlp2(test_text)
        for ent in doc2.ents:
            print(ent.label_, ent.text)

main()
# Out:
# Created blank 'en' model
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))
# {'ner': 216.90629269221313}
# {'ner': 109.45352817916894}
# {'ner': 78.419865913078496}
# {'ner': 63.210563657110768}
# {'ner': 52.258344089209793}
# {'ner': 42.44354678841691}
# {'ner': 38.324832887251532}
# {'ner': 30.823337498877148}
# {'ner': 27.225512379928009}
# {'ner': 22.839966388407102}
# {'ner': 21.590503314773812}
# {'ner': 21.766772920194221}
# {'ner': 16.895602929831362}
# {'ner': 14.863990518194317}
# {'ner': 15.913148859965519}
# {'ner': 14.586008178955014}
# {'ner': 13.939061192643061}
# {'ner': 11.328613838895578}
# {'ner': 12.169256670453604}
# {'ner': 11.155785641661726}
# {'ner': 10.994515924842492}
# {'ner': 12.636921556061941}
# {'ner': 8.9722627688480738}
# {'ner': 8.9621050441901762}
# {'ner': 7.5129150295587319}
# {'ner': 8.179202538388056}
# {'ner': 9.2422652486652339}
# {'ner': 6.4460833579917924}
# {'ner': 7.6254772838604366}
# {'ner': 7.3543577422067887}
# {'ner': 7.0243018144568614}
# {'ner': 6.6855773852329108}
# {'ner': 8.2118928897180794}
# {'ner': 5.4291756471984138}
# {'ner': 5.602163444032831}
# {'ner': 4.9567764941771362}
# {'ner': 4.5025161022257798}
# {'ner': 5.0162638789354332}
# {'ner': 5.2916722389673634}
# {'ner': 4.6770208553493715}
# {'ner': 3.5141867662838213}
# {'ner': 5.7049764440355011}
# {'ner': 6.7733052042788051}
# {'ner': 5.860621486022997}
# {'ner': 4.478184413771503}
# {'ner': 5.1318220005631261}
# {'ner': 5.8976375371695182}
# {'ner': 4.2563633228593245}
# {'ner': 3.6383734186410694}
# {'ner': 3.6442435641612221}
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 1444.0 ON DATE 2018-05-19 04:20:21 PM BY UPI REF NO 813916610352.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 1444.0
# DATE OF TRANSACTION 2018-05-19
# TIME OF TRANSACTION 04:20:21 PM
# REFERENCE NO 813916610352
# Saved model to C:\Users\Simrandeep\Desktop\Think\ner output\debit
# Loading from C:\Users\Simrandeep\Desktop\Think\ner output\debit
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 1444.0
# DATE OF TRANSACTION 2018-05-19
# TIME OF TRANSACTION 04:20:21 PM
# REFERENCE NO 813916610352

# %%
test_text=['TRANX OF GBP 29.99 USING CREDIT CARD 4XXX6002 IS MADE AT WWW.THEREGISTER ON 16-JUL-17. AVBL CR LMT:INR 11,210.78, TOTAL CR LMT: INR 33,000.00']

output_dir= 'C:\\Users\\Simrandeep\\Desktop\\Think\\ner output\\debit'

# test the saved model
print("Loading from", output_dir)
for text in test_text:
    print("")
    print("Entities in '%s'" % text)
    nlp2 = spacy.load(output_dir)
    doc2 = nlp2(text)
    for ent in doc2.ents:
        print(ent.label_, ent.text)
# Out:
# Loading from C:\Users\Simrandeep\Desktop\Think\ner output\debit
#
# Entities in 'TRANX OF GBP 29.99 USING CREDIT CARD 4XXX6002 IS MADE AT WWW.THEREGISTER ON 16-JUL-17. AVBL CR LMT:INR 11,210.78, TOTAL CR LMT: INR 33,000.00'
# DEBIT AMOUNT GBP 29.99
# TXN INSTRUMENT CREDIT CARD
# CARD NO 4XXX6002
# VENDOR LIST WWW.THEREGISTER
# DATE OF TRANSACTION 16-JUL-17
# AVAILABLE CREDIT LIMIT INR 11,210.78
# TOTAL CREDIT LIMIT INR 33,000.00

# %%
df = pd.read_excel("C:/Users/Simrandeep/Desktop/test/batch1_22ndjan.xlsx")
df.head()
# Out:
#                                                                                                                                            message
# 0  DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 174.0 ON DATE 2018-06-04 10:12:03 PM BY UPI REF NO 815544439649.DOWNLOAD YONO @ WWW.YONOSBI.COM
# 1  DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 323.0 ON DATE 2018-06-05 02:18:19 PM BY UPI REF NO 815642401830.DOWNLOAD YONO @ WWW.YONOSBI.COM
# 2  DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 259.0 ON DATE 2018-06-07 03:46:15 PM BY UPI REF NO 815845332392.DOWNLOAD YONO @ WWW.YONOSBI.COM
# 3  DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 5000.0 ON DATE 2018-07-03 07:38:51 PM BY UPI REF NO 818419568485.DOWNLOAD YONO @ WWW.YONOSBI.COM
# 4  DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 4391.0 ON DATE 2018-07-28 12:02:18 PM BY UPI REF NO 820936971166.DOWNLOAD YONO @ WWW.YONOSBI.COM

# %%
pd.set_option('display.max_colwidth', -1)
df['message']=[re.sub(repl="", string=word, pattern= "DOWNLOAD YONO @ WWW.YONOSBI.COM") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "IF NOT DONE BY YOU, FORWARD THIS SMS FROM MOBILE NUMBER REGISTERED WITH SBI TO 9223008333 TO BLOCK YOUR CARD.") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "YOU MAY ALSO CALL 1-800-111109") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "PLZ DOWNLOAD BUDDY") for word in df['message']]
df['message']=[re.sub(repl=", REF- ", string=word, pattern= ",REF-") for word in df['message']]
df['message']=[re.sub(repl="TID -", string=word, pattern= "TID-") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "UPDATE YOUR EMAIL ID IN ACCOUNT.") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "FREE TXN ON OTH BANK ATM-5(INCL MAX 3 IN METRO) IN SB A/C ONLY.") for word in df['message']]
df['message']=[re.sub(repl="AVL BAL :", string=word, pattern= "AVL BAL:") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "IF YOU FIND TXN SUSPICIOUS, SEND BLOCKUPI TO 9220092200.") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "TOLLFREE 18002083333 OR 180030113333") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "IF THIS TXN IS NOT DONE BY YOU PLEASE HOTLIST YOUR CARD BY CALLING ON 18004251112 OR 022-40429123.") for word in df['message']]
df['message']=[re.sub(repl="", string=word, pattern= "DOWNLOAD YONO /U00A1 WWW.YONOSBI.COM") for word in df['message']]
df['message']=[re.sub(repl=". INFO:", string=word, pattern= ".INFO:") for word in df['message']]
df['message']=[re.sub(repl="TOT BAL :", string=word, pattern= "TOT BAL:") for word in df['message']]
df['message']=[re.sub(repl=". AVL", string=word, pattern= ".AVL") for word in df['message']]
df['message'].head()
# Out:
# 0    DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 174.0 ON DATE 2018-06-04 10:12:03 PM BY UPI REF NO 815544439649.
# 1    DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 323.0 ON DATE 2018-06-05 02:18:19 PM BY UPI REF NO 815642401830.
# 2    DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 259.0 ON DATE 2018-06-07 03:46:15 PM BY UPI REF NO 815845332392.
# 3    DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 5000.0 ON DATE 2018-07-03 07:38:51 PM BY UPI REF NO 818419568485.
# 4    DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 4391.0 ON DATE 2018-07-28 12:02:18 PM BY UPI REF NO 820936971166.
# Name: message, dtype: object

# %%
output_dir= 'C:\\Users\\Simrandeep\\Desktop\\Think\\ner output\\debit'
# test the saved model
i=0
print("Loading from", output_dir)
for i in range(df.shape[0]):
    text=df.loc[i,"message"]
    print("")
    print("Entities in '%s'" % text)
    nlp2 = spacy.load(output_dir)
    doc2 = nlp2(text)
    for ent in doc2.ents:
        print(ent.label_, ent.text)
        if 'DEBIT AMOUNT' in ent.label_:
            df.loc[i,'DEBIT AMOUNT']= ent.text
        elif 'DATE OF TRANSACTION' in ent.label_:
            df.loc[i,'DATE OF TRANSACTION']= ent.text
        elif 'TIME OF TRANSACTION' in ent.label_:
            df.loc[i,'TIME OF TRANSACTION']= ent.text
        elif 'REFERENCE NO' in ent.label_:
            df.loc[i,'REFERENCE NO']= ent.text
        elif 'ACCOUNT NO' in ent.label_:
            df.loc[i,'ACCOUNT NO']= ent.text
        elif 'TOTAL BALANCE' in ent.label_:
            df.loc[i,'TOTAL BALANCE']= ent.text
        elif 'CARD NO' in ent.label_:
            df.loc[i,'CARD NO']= ent.text
        elif 'LEDGER BALANCE' in ent.label_:
            df.loc[i,'LEDGER BALANCE']= ent.text
        elif 'AVAILABLE CREDIT LIMIT' in ent.label_:
            df.loc[i,'AVAILABLE CREDIT LIMIT']= ent.text
        elif 'COMBINED BALANCE' in ent.label_:
            df.loc[i,'COMBINED BALANCE']= ent.text
        elif 'CHEQUE NO' in ent.label_:
            df.loc[i,'CHEQUE NO']= ent.text
        elif 'CLEARING BALANCE' in ent.label_:
            df.loc[i,'CLEARING BALANCE']= ent.text
        elif 'VENDOR LIST' in ent.label_:
            df.loc[i,'VENDOR LIST']= ent.text
        elif 'ACCOUNT BALANCE' in ent.label_:
            df.loc[i,'ACCOUNT BALANCE']= ent.text
        elif 'TOTAL CREDIT LIMIT' in ent.label_:
            df.loc[i,'TOTAL CREDIT LIMIT']= ent.text
        elif 'CURRENT OUTSTANDING' in ent.label_:
            df.loc[i,'CURRENT OUTSTANDING']= ent.text
        elif 'BENEFICIARY NAME' in ent.label_:
            df.loc[i,'BENEFICIARY NAME']= ent.text
        elif 'BENEFICIARY ACCOUNT' in ent.label_:
            df.loc[i,'BENEFICIARY ACCOUNT']= ent.text    
        elif 'TXN INSTRUMENT' in ent.label_:
            df.loc[i,'TXN INSTRUMENT']= ent.text
# Out:
# Loading from C:\Users\Simrandeep\Desktop\Think\ner output\debit
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 174.0 ON DATE 2018-06-04 10:12:03 PM BY UPI REF NO 815544439649.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 174.0
# DATE OF TRANSACTION 2018-06-04
# TIME OF TRANSACTION 10:12:03 PM
# REFERENCE NO 815544439649
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 323.0 ON DATE 2018-06-05 02:18:19 PM BY UPI REF NO 815642401830.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 323.0
# DATE OF TRANSACTION 2018-06-05
# TIME OF TRANSACTION 02:18:19 PM
# REFERENCE NO 815642401830
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 259.0 ON DATE 2018-06-07 03:46:15 PM BY UPI REF NO 815845332392.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 259.0
# DATE OF TRANSACTION 2018-06-07
# TIME OF TRANSACTION 03:46:15 PM
# REFERENCE NO 815845332392
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 5000.0 ON DATE 2018-07-03 07:38:51 PM BY UPI REF NO 818419568485.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 5000.0
# DATE OF TRANSACTION 2018-07-03
# TIME OF TRANSACTION 07:38:51 PM
# REFERENCE NO 818419568485
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 4391.0 ON DATE 2018-07-28 12:02:18 PM BY UPI REF NO 820936971166.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 4391.0
# DATE OF TRANSACTION 2018-07-28
# TIME OF TRANSACTION 12:02:18 PM
# REFERENCE NO 820936971166
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 7000.0 ON DATE 2018-07-30 05:35:21 PM BY UPI REF NO 821168761006.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 7000.0
# DATE OF TRANSACTION 2018-07-30
# TIME OF TRANSACTION 05:35:21 PM
# REFERENCE NO 821168761006
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 6432.0 ON DATE 2018-08-02 03:34:27 PM BY UPI REF NO 821415623791.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 6432.0
# DATE OF TRANSACTION 2018-08-02
# TIME OF TRANSACTION 03:34:27 PM
# REFERENCE NO 821415623791
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 49.0 ON DATE 2018-08-10 06:40:03 PM BY UPI REF NO 822254500619.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 49.0
# DATE OF TRANSACTION 2018-08-10
# TIME OF TRANSACTION 06:40:03 PM
# REFERENCE NO 822254500619
#
# Entities in 'THANK YOU FOR USING STATE BANK INTERNET BANKING. REFERENCE NO. FOR IRCTC-RAILWAY TICKET BOOK TRANSACTION OF RS. 1121.8 FROM A/C ENDING 7972 ON 27-MAY-18 AT 19:45 IS IGADPMMZF7.'
# TXN INSTRUMENT INTERNET BANKING
# VENDOR LIST IRCTC-RAILWAY TICKET BOOK
# DEBIT AMOUNT RS. 1121.8
# CARD NO 7972
# DATE OF TRANSACTION 27-MAY-18
# TIME OF TRANSACTION 19:45
# REFERENCE NO IGADPMMZF7
#
# Entities in 'THANK YOU FOR USING STATE BANK INTERNET BANKING. REFERENCE NO. FOR SBICARD FOR BILLDESK TRANSACTION OF RS. 1500.0 FROM A/C ENDING 7972 ON 18-JUN-18 AT 21:23 IS IGADTMIKE3.'
# TXN INSTRUMENT INTERNET BANKING
# DEBIT AMOUNT RS. 1500.0
# CARD NO 7972
# DATE OF TRANSACTION 18-JUN-18
# TIME OF TRANSACTION 21:23
# REFERENCE NO IGADTMIKE3
#
# Entities in 'THANK YOU FOR USING STATE BANK INTERNET BANKING. REFERENCE NO. FOR IRCTC-RAILWAY TICKET BOOK TRANSACTION OF RS. 346.8 FROM A/C ENDING 7972 ON 04-JUL-18 AT 11:22 IS IGADWVLEM7.'
# TXN INSTRUMENT INTERNET BANKING
# VENDOR LIST IRCTC-RAILWAY TICKET BOOK
# DEBIT AMOUNT RS. 346.8
# CARD NO 7972
# DATE OF TRANSACTION 04-JUL-18
# TIME OF TRANSACTION 11:22
# REFERENCE NO IGADWVLEM7
#
# Entities in 'THANK YOU FOR USING YOUR SBI DEBIT CARD 478XX1551 FOR A PURCHASE WORTH RS271.2 ON POS VENUE SUPERMART AT AVENUE SUPERMARTS TXN# 820214204793. '
# TXN INSTRUMENT DEBIT CARD
# CARD NO 478XX1551
# DEBIT AMOUNT RS271.2
# VENDOR LIST AVENUE SUPERMARTS
# REFERENCE NO 820214204793
#
# Entities in 'RS 10000 WITHDRAWN FROM A/C XX 7972 ON 29/07/18 AT UBI ATM AMUM0160.TXN# 821012007033 . AVL BAL RS 6702.56.  '
# DEBIT AMOUNT RS 10000
# ACCOUNT NO 7972
# DATE OF TRANSACTION 29/07/18
# VENDOR LIST UBI ATM
# REFERENCE NO 821012007033
# TOTAL BALANCE RS 6702.56
#
# Entities in 'RS 1000 WITHDRAWN FROM A/C XX 7972 ON 02/08/18 AT AXS ATM DWCW2064.TXN# 821421022175 . AVL BAL RS 18517.56.  '
# DEBIT AMOUNT RS 1000
# ACCOUNT NO 7972
# DATE OF TRANSACTION 02/08/18
# VENDOR LIST AXS ATM
# REFERENCE NO 821421022175
# TOTAL BALANCE RS 18517.56
#
# Entities in 'RS 200 WITHDRAWN FROM A/C XX 7972 ON 07/08/18 AT ICI ATM S1CWE628.TXN# 821912004697 . AVL BAL RS 187.56.  '
# DEBIT AMOUNT RS 200
# ACCOUNT NO 7972
# DATE OF TRANSACTION 07/08/18
# VENDOR LIST ICI ATM
# REFERENCE NO 821912004697
# TOTAL BALANCE RS 187.56
#
# Entities in 'RS. 40 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: UPI/817763666459.TOT BAL :2984.05CR. AVL AMT:- 2984.05(26-06-2018 21:01:12)'
# DEBIT AMOUNT RS. 40
# ACCOUNT NO *********002707
# TOTAL BALANCE 2984.05CR
# DATE OF TRANSACTION 2984.05(26-06-2018
# TIME OF TRANSACTION 21:01:12
#
# Entities in 'RS. 130 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: ACH/ECS MANDATE REGISTRATION C.TOT BAL :500.05CR. AVL AMT:- 500.05(29-06-2018 16:36:45)'
# DEBIT AMOUNT RS. 130
# ACCOUNT NO *********002707
# DATE OF TRANSACTION 500.05(29-06-2018
# TIME OF TRANSACTION 16:36:45
#
# Entities in 'RS. 100 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: UPI/819160132623.TOT BAL :587.05CR. AVL AMT:- 587.05(10-07-2018 15:34:32)'
# DEBIT AMOUNT RS. 100
# ACCOUNT NO *********002707
# DATE OF TRANSACTION 587.05(10-07-2018
# TIME OF TRANSACTION 15:34:32
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 3000.000 ON 03-07-18 . A/C BAL IS RS. 21868.52 CR AND. AVL BAL IS RS. 21868.52( UPI REF NO. 818414997041 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 3000.000
# DATE OF TRANSACTION 03-07-18
# ACCOUNT BALANCE RS. 21868.52
# TOTAL BALANCE RS. 21868.52
# TXN INSTRUMENT UPI
# REFERENCE NO 818414997041
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 1,200.00 ON 08-AUG-2018. A/C BAL IS RS. 2,910.02 CR AND. AVL BAL IS RS. 2,910.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 1,200.00
# DATE OF TRANSACTION 08-AUG-2018
# ACCOUNT BALANCE RS. 2,910.02
# TOTAL BALANCE RS. 2,910.02
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 500.000 ON 08-08-18 . A/C BAL IS RS. 1433.02 CR AND. AVL BAL IS RS. 1433.02( UPI REF NO. 822020801140 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 500.000
# DATE OF TRANSACTION 08-08-18
# ACCOUNT BALANCE RS. 1433.02
# TOTAL BALANCE RS. 1433.02
# TXN INSTRUMENT UPI
# REFERENCE NO 822020801140
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 700.00 ON 10-AUG-2018 VIA 62609807/652155XXXXXX5990/822219013416. A/C NO XXXX2833 BAL IS RS. 613.02 CR AND. AVL BAL IS RS. 613.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 700.00
# DATE OF TRANSACTION 10-AUG-2018
# TIME OF TRANSACTION 62609807/652155XXXXXX5990/822219013416
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 613.02
# TOTAL BALANCE RS. 613.02
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 500.00 ON 16-AUG-2018. A/C BAL IS RS. 38.02 CR AND. AVL BAL IS RS. 38.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 500.00
# DATE OF TRANSACTION 16-AUG-2018
# ACCOUNT BALANCE RS. 38.02
# TOTAL BALANCE RS. 38.02
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 500.00.. AVL BAL RS. 1.98. MIN BAL NOT MAINTAINED. PL MAINTAIN.'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 500.00
# TOTAL BALANCE RS. 1.98
#
# Entities in 'RS. 160.00 WAS SPENT ON YOUR ATM CARD NO. ENDING XXXX5990 PVR LTD ON 03-JUL-2018. A/C NO XXXX2833 BAL IS RS. 5,708.52 CR AND. AVL BAL IS RS. 5,708.52'
# DEBIT AMOUNT RS. 160.00
# TXN INSTRUMENT ATM CARD
# CARD NO XXXX5990
# DATE OF TRANSACTION 03-JUL-2018
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 5,708.52
# TOTAL BALANCE RS. 5,708.52
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 55.00 ON 04-JUL-2018. A/C BAL IS RS. 3,885.52 CR AND. AVL BAL IS RS. 3,885.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 55.00
# DATE OF TRANSACTION 04-JUL-2018
# ACCOUNT BALANCE RS. 3,885.52
# TOTAL BALANCE RS. 3,885.52
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 1,000.00 ON 05-JUL-2018. A/C BAL IS RS. 2,385.52 CR AND. AVL BAL IS RS. 2,385.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 1,000.00
# DATE OF TRANSACTION 05-JUL-2018
# ACCOUNT BALANCE RS. 2,385.52
# TOTAL BALANCE RS. 2,385.52
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 250.000 ON 05-07-18 . A/C BAL IS RS. 2146.52 CR AND. AVL BAL IS RS. 2146.52( UPI REF NO. 818644264177 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 250.000
# DATE OF TRANSACTION 05-07-18
# ACCOUNT BALANCE RS. 2146.52
# TOTAL BALANCE RS. 2146.52
# TXN INSTRUMENT UPI
# REFERENCE NO 818644264177
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 94.50 ON 07-JUL-2018. A/C BAL IS RS. 552.02 CR AND. AVL BAL IS RS. 552.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 94.50
# DATE OF TRANSACTION 07-JUL-2018
# ACCOUNT BALANCE RS. 552.02
# TOTAL BALANCE RS. 552.02
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 55.000 ON 10-07-18 . A/C BAL IS RS. 426.02 CR AND. AVL BAL IS RS. 426.02( UPI REF NO. 819140574257 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 55.000
# DATE OF TRANSACTION 10-07-18
# ACCOUNT BALANCE RS. 426.02
# TOTAL BALANCE RS. 426.02
# TXN INSTRUMENT UPI
# REFERENCE NO 819140574257
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 500.00 ON 19-JUL-2018 VIA TJ007901/652155XXXXXX5990/820012514937. A/C NO XXXX2833 BAL IS RS. 22.02 CR AND. AVL BAL IS RS. 22.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 500.00
# DATE OF TRANSACTION 19-JUL-2018
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 22.02
# TOTAL BALANCE RS. 22.02
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 3,000.00 ON 01-JUL-2018. A/C BAL IS RS. 25,868.52 CR AND. AVL BAL IS RS. 25,868.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 3,000.00
# DATE OF TRANSACTION 01-JUL-2018
# ACCOUNT BALANCE RS. 25,868.52
# TOTAL BALANCE RS. 25,868.52
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 149.00 ON 04-AUG-2018. A/C BAL IS RS. 28,653.02 CR AND. AVL BAL IS RS. 28,653.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 149.00
# DATE OF TRANSACTION 04-AUG-2018
# ACCOUNT BALANCE RS. 28,653.02
# TOTAL BALANCE RS. 28,653.02
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 5,000.00 ON 04-AUG-2018. A/C BAL IS RS. 19,653.02 CR AND. AVL BAL IS RS. 19,653.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 5,000.00
# DATE OF TRANSACTION 04-AUG-2018
# ACCOUNT BALANCE RS. 19,653.02
# TOTAL BALANCE RS. 19,653.02
#
# Entities in 'YOUR A/C XXXXX980541 HAS A CASH WITHDRAWAL OF RS 500.00 ON 18/07/18 .. AVL BAL RS 523.65. '
# ACCOUNT NO XXXXX980541
# DEBIT AMOUNT RS 500.00
# DATE OF TRANSACTION 18/07/18
# TOTAL BALANCE RS 523.65
#
# Entities in 'YOUR A/C NO. XXXXXXXX5155 IS DEBITED FOR RS.10.00 ON 24-07-18 AND A/C XXXXXXX3918 CREDITED (IMPS REF NO 820521015467).'
# ACCOUNT NO XXXXXXXX5155
# DEBIT AMOUNT RS.10.00
# DATE OF TRANSACTION 24-07-18
# ACCOUNT NO XXXXXXX3918
# TXN INSTRUMENT IMPS
# REFERENCE NO 820521015467
#
# Entities in 'DEAR F , TRANSFER OF RS.5000 TO MR JUBER HAS BEEN SUCCESSFUL WITH REF NO:LDUDBH3'
# DEBIT AMOUNT RS.5000
# BENEFICIARY NAME MR JUBER
# REFERENCE NO LDUDBH3
#
# Entities in 'DEAR F , TRANSFER OF RS.999 TO KAMAR ALI HAS BEEN SUCCESSFUL WITH REF NO:LDWQWLA'
# DEBIT AMOUNT RS.999
# BENEFICIARY NAME KAMAR ALI
# REFERENCE NO LDWQWLA
#
# Entities in 'YOUR A/C XXXXXXX4392 IS DEBITED THROUGH ATM BY RS. 200 TOTAL BAL : RS. 797.76 CR CLR BAL : RS. 797.76 CR 12/07/2018 -- 12/07/18 14:41 - ALB'
# ACCOUNT NO XXXXXXX4392
# TXN INSTRUMENT ATM
# DEBIT AMOUNT RS. 200
# TOTAL BALANCE RS. 797.76
# CLEARING BALANCE RS. 797.76
# DATE OF TRANSACTION 12/07/2018 -- 12/07/18
# TIME OF TRANSACTION 14:41
# TXN INSTRUMENT ALB
#
# Entities in 'YOUR A/C XXXXXXX4392 IS DEBITED BY RS. 518 BAL AFTER DEBIT IS RS. 76.21 CR 23/07/2018. MINIMUM BAL NOT MAINTAINED.PL FUND YOUR A/C. -- 23/07/18 13:02 - ALB '
# ACCOUNT NO XXXXXXX4392
# DEBIT AMOUNT RS. 518
# TOTAL BALANCE RS. 76.21
# DATE OF TRANSACTION 23/07/2018
# TIME OF TRANSACTION 13:02
# TXN INSTRUMENT ALB
#
# Entities in 'HELLO! YOUR A/C NO. 885287 HAS BEEN DEBITED BY RS. 15005.9 ON 31JUL18. THE A/C BALANCE IS RS. 29847.80. INFO: IMPS/P2A/821213170309/0290104000225298IB. CALL 18605005555 (IF IN INDIA) IF YOU HAVE NOT DONE THIS TRANSACTION.'
# ACCOUNT NO 885287
# DEBIT AMOUNT RS. 15005.9
# DATE OF TRANSACTION 31JUL18
# ACCOUNT BALANCE RS. 29847.80
# TXN INSTRUMENT IMPS
#
# Entities in 'HELLO! YOUR A/C NO. 885287 HAS BEEN DEBITED BY RS. 15005.9 ON 31JUL18. THE A/C BALANCE IS RS. 16341.90. INFO: IMPS/P2A/821213177367/366105000169ICIC00. CALL 18605005555 (IF IN INDIA) IF YOU HAVE NOT DONE THIS TRANSACTION.'
# ACCOUNT NO 885287
# DEBIT AMOUNT RS. 15005.9
# DATE OF TRANSACTION 31JUL18
# ACCOUNT BALANCE RS. 16341.90
# TXN INSTRUMENT IMPS
#
# Entities in 'HELLO! YOUR A/C NO. 885287 HAS BEEN DEBITED BY RS. 1000 ON 08AUG18. THE A/C BALANCE IS RS. 2354.10. INFO: IMPS/P2A/822013888445/34805125605SBIN001. CALL 18605005555 (IF IN INDIA) IF YOU HAVE NOT DONE THIS TRANSACTION.'
# ACCOUNT NO 885287
# DEBIT AMOUNT RS. 1000
# DATE OF TRANSACTION 08AUG18
# ACCOUNT BALANCE RS. 2354.10
# TXN INSTRUMENT IMPS
#
# Entities in 'RS.24.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-05-22:21:33:20 AT FXMART68592. AVL BAL - RS.3261.00, CURR O/S - RS.20739.00'
# DEBIT AMOUNT RS.24.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-05-22:21:33:20
# VENDOR LIST FXMART68592
# TOTAL BALANCE RS.3261.00
# CURRENT OUTSTANDING RS.20739.00
#
# Entities in 'RS.110.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-05-25:21:38:15 AT SRINIVASA FANCY AND GENER. AVL BAL - RS.2829.16, CURR O/S - RS.21170.84'
# DEBIT AMOUNT RS.110.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-05-25:21:38:15
# VENDOR LIST SRINIVASA FANCY AND GENER
# TOTAL BALANCE RS.2829.16
# CURRENT OUTSTANDING RS.21170.84
#
# Entities in 'THANK YOU FOR USING DEBIT CARD ENDING 3295 FOR RS.50.00 IN G.CO/HELPPAY# AT GOOGLE *SERVICES ON 2018-02-16:23:23:47. AVL BAL : RS.858.16'
# TXN INSTRUMENT DEBIT CARD
# CARD NO 3295
# DEBIT AMOUNT RS.50.00
# VENDOR LIST GOOGLE *SERVICES
# DATE OF TRANSACTION 2018-02-16:23:23:47
# TOTAL BALANCE RS.858.16
#
# Entities in 'RS.680.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-05-31:01:39:52 AT GMR HYDERABAD INTERNATION. AVL BAL - RS.1116.73, CURR O/S - RS.22883.27'
# DEBIT AMOUNT RS.680.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-05-31:01:39:52
# VENDOR LIST GMR HYDERABAD INTERNATION
# TOTAL BALANCE RS.1116.73
# CURRENT OUTSTANDING RS.22883.27
#
# Entities in 'RS.520.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-06-03:21:06:00 AT SRI ANJANEYA RESTAURAN. AVL BAL - RS.19222.00, CURR O/S - RS.4778.00'
# DEBIT AMOUNT RS.520.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-06-03:21:06:00
# VENDOR LIST SRI ANJANEYA RESTAURAN
# TOTAL BALANCE RS.19222.00
# CURRENT OUTSTANDING RS.4778.00
#
# Entities in 'RS.879.17 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-06-10:20:44:16 AT IOCL RUNWAY FILLING ST. AVL BAL - RS.1087.23, CURR O/S - RS.22912.77'
# DEBIT AMOUNT RS.879.17
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-06-10:20:44:16
# VENDOR LIST IOCL RUNWAY FILLING ST
# TOTAL BALANCE RS.1087.23
# CURRENT OUTSTANDING RS.22912.77
#
# Entities in 'RS.520.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-07-05:13:23:13 AT THE ANDHRA ENGIN. AVL BAL - RS.23119.49, CURR O/S - RS.880.51'
# DEBIT AMOUNT RS.520.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-07-05:13:23:13
# TOTAL BALANCE RS.23119.49
# CURRENT OUTSTANDING RS.880.51
#
# Entities in 'DEAR SMART PAY CUSTOMER,WE HAVE SUCCESSFULLY DEBITED YOUR HDFC BANK CREDIT CARD ENDING 6922 TO PAY YOUR SPAY 8374543786 BILL FOR THE AMOUNT RS 100'
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DEBIT AMOUNT RS 100
#
# Entities in 'THANK YOU FOR USING DEBIT CARD ENDING 3295 FOR RS.500.00 IN MUMBAI AT RAILRBOTHDRCARD ON 2018-03-12:12:13:51. AVL BAL : RS.764.16'
# TXN INSTRUMENT DEBIT CARD
# CARD NO 3295
# DEBIT AMOUNT RS.500.00
# VENDOR LIST RAILRBOTHDRCARD
# DATE OF TRANSACTION 2018-03-12:12:13:51
# TOTAL BALANCE RS.764.16
#
# Entities in 'THANK YOU FOR USING DEBIT CARD ENDING 3295 FOR RS.370.00 IN NEW DELHI AT IRCTC11779 ON 2018-04-07:14:35:56. AVL BAL : RS.1067.16'
# TXN INSTRUMENT DEBIT CARD
# CARD NO 3295
# DEBIT AMOUNT RS.370.00
# ACCOUNT NO IRCTC11779
# DATE OF TRANSACTION 2018-04-07:14:35:56
# TOTAL BALANCE RS.1067.16
#
# Entities in 'YOUR RECHARGE FOR BSNL PREPAID - ACCOUNT 8374543786 FOR RS 50.00 HAS BEEN RECEIVED AND RECHARGE WILL BE INITIATED WITH THE OPERATOR SHORTLY.'
# ACCOUNT NO 8374543786
# DEBIT AMOUNT RS 50.00
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 720.0 ON DATE 2018-06-04 06:00:06 PM BY UPI REF NO 815572059932.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 720.0
# DATE OF TRANSACTION 2018-06-04
# TIME OF TRANSACTION 06:00:06 PM
# REFERENCE NO 815572059932
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 10.0 ON DATE 2018-06-07 07:15:47 AM BY UPI REF NO 815807690877.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 10.0
# DATE OF TRANSACTION 2018-06-07
# TIME OF TRANSACTION 07:15:47 AM
# REFERENCE NO 815807690877
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 102.0 ON DATE 2018-06-30 06:42:13 PM BY UPI REF NO 818172649526.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 102.0
# DATE OF TRANSACTION 2018-06-30
# TIME OF TRANSACTION 06:42:13 PM
# REFERENCE NO 818172649526
#
# Entities in 'DEAR SBI UPI USER, YOUR ACCOUNT IS DEBITED INR 5000.0 ON DATE 2018-07-30 04:53:58 PM BY UPI REF NO 821164290228.'
# TXN INSTRUMENT UPI
# DEBIT AMOUNT INR 5000.0
# DATE OF TRANSACTION 2018-07-30
# TIME OF TRANSACTION 04:53:58 PM
# REFERENCE NO 821164290228
#
# Entities in 'RS.577.00 WAS SPENT ON YOUR SBI CARD ENDING 5320 AT VODAFONE INDIA LTD ON 21/06/18. AVAILABLE CREDIT LIMIT: RS.646.47. DOWNLOAD APP AT HTTPS://GOO.GL/B7QDQU'
# DEBIT AMOUNT RS.577.00
# CARD NO 5320
# VENDOR LIST VODAFONE INDIA LTD
# DATE OF TRANSACTION 21/06/18
# AVAILABLE CREDIT LIMIT RS.646.47
#
# Entities in 'RS.229.00 WAS SPENT ON YOUR SBI CARD ENDING 5320 AT DOMINOS PIZZA. ON 21/06/18. AVAILABLE CREDIT LIMIT: RS.417.47. DOWNLOAD APP AT HTTPS://GOO.GL/B7QDQU'
# DEBIT AMOUNT RS.229.00
# CARD NO 5320
# VENDOR LIST DOMINOS PIZZA
# DATE OF TRANSACTION 21/06/18
# AVAILABLE CREDIT LIMIT RS.417.47
#
# Entities in 'RS.54.46 WAS SPENT ON YOUR SBI CARD ENDING 0788 AT HAIKO SUPER MARKET ON 24/06/18. AVAILABLE CREDIT LIMIT: RS.126.57. DOWNLOAD APP AT HTTPS://GOO.GL/B7QDQU'
# DEBIT AMOUNT RS.54.46
# CARD NO 0788
# VENDOR LIST HAIKO SUPER MARKET
# DATE OF TRANSACTION 24/06/18
# AVAILABLE CREDIT LIMIT RS.126.57
#
# Entities in 'YOUR AC XXXXX187972 DEBITED INR 25.00 ON 26/06/18 -CDM CHARGE DR .. AVL BAL INR 21,872.43.'
# ACCOUNT NO XXXXX187972
# DEBIT AMOUNT INR 25.00
# DATE OF TRANSACTION 26/06/18
# TOTAL BALANCE INR 21,872.43
#
# Entities in 'RS 3000 WITHDRAWN FROM A/C XX 7972 ON 17/07/18 AT AXS ATM DWCW2064.TXN# 819809032237 . AVL BAL RS 6137.41.  '
# DEBIT AMOUNT RS 3000
# ACCOUNT NO 7972
# DATE OF TRANSACTION 17/07/18
# VENDOR LIST AXS ATM
# REFERENCE NO 819809032237
# TOTAL BALANCE RS 6137.41
#
# Entities in 'YOUR AC XXXXX187972 DEBITED INR 25.00 ON 28/07/18 -CDM CHARGE DR .. AVL BAL INR 15,093.56.'
# ACCOUNT NO XXXXX187972
# DEBIT AMOUNT INR 25.00
# DATE OF TRANSACTION 28/07/18
# TOTAL BALANCE INR 15,093.56
#
# Entities in 'THANK YOU FOR USING YOUR SBI DEBIT CARD 478XX1551 FOR A PURCHASE WORTH RS2007.0 ON POS 470000097012201 AT 21 AUTO INDIA PVT LTD TXN# 821512927805. '
# TXN INSTRUMENT DEBIT CARD
# CARD NO 478XX1551
# DEBIT AMOUNT RS2007.0
# VENDOR LIST 21 AUTO INDIA PVT LTD
# REFERENCE NO 821512927805
#
# Entities in 'YOUR A/C XXXXX187972 HAS A DEBIT BY TRANSFER OF RS 3,860.00 ON 06/08/18.. AVL BAL RS 387.56.'
# ACCOUNT NO XXXXX187972
# DEBIT AMOUNT RS 3,860.00
# DATE OF TRANSACTION 06/08/18
# TOTAL BALANCE RS 387.56
#
# Entities in 'RS. 1285 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: UPI/817048244324.TOT BAL :806.05CR. AVL AMT:- 806.05(19-06-2018 12:40:23)'
# DEBIT AMOUNT RS. 1285
# ACCOUNT NO *********002707
# ACCOUNT BALANCE 806.05CR.
# DATE OF TRANSACTION 806.05(19-06-2018
# TIME OF TRANSACTION 12:40:23
#
# Entities in 'RS. 4500 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: NFSD/VA022701//16:46:44/817216.TOT BAL :1307.05CR. AVL AMT:- 1307.05(21-06-2018 16:45:14)'
# DEBIT AMOUNT RS. 4500
# ACCOUNT NO *********002707
# TOTAL BALANCE 1307.05CR
# DATE OF TRANSACTION 1307.05(21-06-2018
# TIME OF TRANSACTION 16:45:14
#
# Entities in 'RS. 333 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: POS/BARODA G/DMART/81751.TOT BAL :3024.05CR. AVL AMT:- 3024.05(24-06-2018 10:12:02)'
# DEBIT AMOUNT RS. 333
# ACCOUNT NO *********002707
# TOTAL BALANCE 3024.05CR
# DATE OF TRANSACTION 3024.05(24-06-2018
# TIME OF TRANSACTION 10:12:02
#
# Entities in 'RS. 1500 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: NFSD/IDBI VADOD//14:24:03/8180.TOT BAL :630.05CR. AVL AMT:- 630.05(29-06-2018 14:22:21)'
# DEBIT AMOUNT RS. 1500
# ACCOUNT NO *********002707
# DATE OF TRANSACTION 630.05(29-06-2018
# TIME OF TRANSACTION 14:22:21
#
# Entities in 'RS. 1525 WITHDRAWN FROM YOUR A/C *********002707 DETAILS: 4005196651 TP ACH CAPITAL FIRS.TOT BAL :475.05CR. AVL AMT:- 475.05(02-07-2018 12:01:52)'
# DEBIT AMOUNT RS. 1525
# ACCOUNT NO *********002707
# CHEQUE NO 4005196651
# DATE OF TRANSACTION 475.05(02-07-2018
# TIME OF TRANSACTION 12:01:52
#
# Entities in 'YOUR A/C NO. XXXXXXXX2707 IS DEBITED FOR RS.100.00 ON 10-07-18 (UPI REF NO 819160132623)'
# ACCOUNT NO XXXXXXXX2707
# DEBIT AMOUNT RS.100.00
# DATE OF TRANSACTION 10-07-18
# TXN INSTRUMENT UPI
# REFERENCE NO 819160132623
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 1200.000 ON 08-08-18 . A/C BAL IS RS. 2910.02 CR AND. AVL BAL IS RS. 2910.02( UPI REF NO. 822038842944 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 1200.000
# DATE OF TRANSACTION 08-08-18
# ACCOUNT BALANCE RS. 2910.02
# TOTAL BALANCE RS. 2910.02
# TXN INSTRUMENT UPI
# REFERENCE NO 822038842944
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 3,000.00 ON 03-JUL-2018. A/C BAL IS RS. 18,868.52 CR AND. AVL BAL IS RS. 18,868.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 3,000.00
# DATE OF TRANSACTION 03-JUL-2018
# ACCOUNT BALANCE RS. 18,868.52
# TOTAL BALANCE RS. 18,868.52
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 100.00 ON 09-AUG-2018. A/C BAL IS RS. 1,333.02 CR AND. AVL BAL IS RS. 1,333.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 100.00
# DATE OF TRANSACTION 09-AUG-2018
# ACCOUNT BALANCE RS. 1,333.02
# TOTAL BALANCE RS. 1,333.02
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 500.00 ON 13-AUG-2018 VIA 03670623/652155XXXXXX5990/822511017477. A/C NO XXXX2833 BAL IS RS. 38.02 CR AND. AVL BAL IS RS. 38.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 500.00
# DATE OF TRANSACTION 13-AUG-2018
# TIME OF TRANSACTION 03670623/652155XXXXXX5990/822511017477
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 38.02
# TOTAL BALANCE RS. 38.02
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 500.000 ON 16-08-18 . A/C BAL IS RS. 38.02 CR AND. AVL BAL IS RS. 38.02( UPI REF NO. 822821108160 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 500.000
# DATE OF TRANSACTION 16-08-18
# ACCOUNT BALANCE RS. 38.02
# TOTAL BALANCE RS. 38.02
# TXN INSTRUMENT UPI
# REFERENCE NO 822821108160
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 3000.000 ON 03-07-18 . A/C BAL IS RS. 5868.52 CR AND. AVL BAL IS RS. 5868.52( UPI REF NO. 818408759964 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 3000.000
# DATE OF TRANSACTION 03-07-18
# ACCOUNT BALANCE RS. 5868.52
# TOTAL BALANCE RS. 5868.52
# TXN INSTRUMENT UPI
# REFERENCE NO 818408759964
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 1,500.00 ON 04-JUL-2018 VIA SACW8351/652155XXXXXX5990/818510009853. A/C NO XXXX2833 BAL IS RS. 4,208.52 CR AND. AVL BAL IS RS. 4,208.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 1,500.00
# DATE OF TRANSACTION 04-JUL-2018
# TXN INSTRUMENT SACW8351/652155XXXXXX5990/818510009853
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 4,208.52
# TOTAL BALANCE RS. 4,208.52
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 55.000 ON 04-07-18 . A/C BAL IS RS. 3885.52 CR AND. AVL BAL IS RS. 3885.52( UPI REF NO. 818554869612 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 55.000
# DATE OF TRANSACTION 04-07-18
# ACCOUNT BALANCE RS. 3885.52
# TOTAL BALANCE RS. 3885.52
# TXN INSTRUMENT UPI
# REFERENCE NO 818554869612
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 1000.000 ON 05-07-18 . A/C BAL IS RS. 2385.52 CR AND. AVL BAL IS RS. 2385.52( UPI REF NO. 818610641620 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 1000.000
# DATE OF TRANSACTION 05-07-18
# ACCOUNT BALANCE RS. 2385.52
# TOTAL BALANCE RS. 2385.52
# TXN INSTRUMENT UPI
# REFERENCE NO 818610641620
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 1,000.00 ON 05-JUL-2018. A/C BAL IS RS. 2,396.52 CR AND. AVL BAL IS RS. 2,396.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 1,000.00
# DATE OF TRANSACTION 05-JUL-2018
# ACCOUNT BALANCE RS. 2,396.52
# TOTAL BALANCE RS. 2,396.52
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 94.500 ON 07-07-18 . A/C BAL IS RS. 552.02 CR AND. AVL BAL IS RS. 552.02( UPI REF NO. 818868334752 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 94.500
# DATE OF TRANSACTION 07-07-18
# ACCOUNT BALANCE RS. 552.02
# TOTAL BALANCE RS. 552.02
# TXN INSTRUMENT UPI
# REFERENCE NO 818868334752
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 53.00 ON 08-JUL-2018. A/C BAL IS RS. 481.02 CR AND. AVL BAL IS RS. 481.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 53.00
# DATE OF TRANSACTION 08-JUL-2018
# ACCOUNT BALANCE RS. 481.02
# TOTAL BALANCE RS. 481.02
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 9.000 ON 11-07-18 . A/C BAL IS RS. 26.02 CR AND. AVL BAL IS RS. 26.02( UPI REF NO. 819218023212 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 9.000
# DATE OF TRANSACTION 11-07-18
# ACCOUNT BALANCE RS. 26.02
# TOTAL BALANCE RS. 26.02
# TXN INSTRUMENT UPI
# REFERENCE NO 819218023212
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 1,000.00 ON 25-JUL-2018 VIA TJ007901/652155XXXXXX5990/820609679616. A/C NO XXXX2833 BAL IS RS. 2.02 CR AND. AVL BAL IS RS. 2.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 1,000.00
# DATE OF TRANSACTION 25-JUL-2018
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 2.02
# TOTAL BALANCE RS. 2.02
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 200.00 ON 01-AUG-2018 VIA S1ANNN11/652155XXXXXX5990/821312030926. A/C NO XXXX2833 BAL IS RS. 2.02 CR AND. AVL BAL IS RS. 2.02'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 200.00
# DATE OF TRANSACTION 01-AUG-2018
# ACCOUNT NO XXXX2833
# ACCOUNT BALANCE RS. 2.02
# TOTAL BALANCE RS. 2.02
#
# Entities in 'YOUR A/C NO XXXXXXX2833 HAS BEEN DEBITED BY RS. 149.000 ON 04-08-18 . A/C BAL IS RS. 28653.02 CR AND. AVL BAL IS RS. 28653.02( UPI REF NO. 821611483636 )'
# ACCOUNT NO XXXXXXX2833
# DEBIT AMOUNT RS. 149.000
# DATE OF TRANSACTION 04-08-18
# ACCOUNT BALANCE RS. 28653.02
# TOTAL BALANCE RS. 28653.02
# TXN INSTRUMENT UPI
# REFERENCE NO 821611483636
#
# Entities in 'YOUR A/C NO XXXX2833 HAS BEEN DEBITED BY RS. 2,000.00 ON 01-JUL-2018. A/C BAL IS RS. 23,868.52 CR AND. AVL BAL IS RS. 23,868.52'
# ACCOUNT NO XXXX2833
# DEBIT AMOUNT RS. 2,000.00
# DATE OF TRANSACTION 01-JUL-2018
# ACCOUNT BALANCE RS. 23,868.52
# TOTAL BALANCE RS. 23,868.52
#
# Entities in 'YOUR A/C NO. XXXXXXXX5155 IS DEBITED FOR RS.100.00 ON 11-08-18 AND A/C XXXXXXX4164 CREDITED (IMPS REF NO 822322694694).'
# ACCOUNT NO XXXXXXXX5155
# DEBIT AMOUNT RS.100.00
# DATE OF TRANSACTION 11-08-18
# BENEFICIARY ACCOUNT XXXXXXX4164
# TXN INSTRUMENT IMPS
# REFERENCE NO 822322694694
#
# Entities in 'DEAR F , TRANSFER OF RS.2000 TO MR IMAM ALI HAS BEEN SUCCESSFUL WITH REF NO:LDUDBDK'
# DEBIT AMOUNT RS.2000
# BENEFICIARY NAME MR IMAM ALI
# REFERENCE NO LDUDBDK
#
# Entities in 'YOUR A/C XXXXXXX4392 IS DEBITED THROUGH ATM CARD BY RS. 155 TOTAL BAL : RS. 997.76 CR CLR BAL : RS. 997.76 CR 09/07/2018 -- 09/07/18 20:36 - ALB'
# ACCOUNT NO XXXXXXX4392
# TXN INSTRUMENT ATM CARD
# DEBIT AMOUNT RS. 155
# TOTAL BALANCE RS. 997.76
# CLEARING BALANCE RS. 997.76
# DATE OF TRANSACTION 09/07/2018 -- 09/07/18
# TIME OF TRANSACTION 20:36
# TXN INSTRUMENT ALB
#
# Entities in 'YOUR A/C XXXXXXX4392 IS DEBITED THROUGH ATM BY RS. 1,318 TOTAL BAL : RS. 1,079.76 CR CLR BAL : RS. 1,079.76 CR 20/07/2018 -- 20/07/18 18:29 - ALB'
# ACCOUNT NO XXXXXXX4392
# TXN INSTRUMENT ATM
# DEBIT AMOUNT RS. 1,318
# TOTAL BALANCE RS. 1,079.76
# CLEARING BALANCE RS. 1,079.76
# DATE OF TRANSACTION 20/07/2018 -- 20/07/18
# TIME OF TRANSACTION 18:29
# TXN INSTRUMENT ALB
#
# Entities in 'YOUR A/C NO. XXXXXXXX5287 IS DEBITED FOR RS.15000.00 ON 31-07-18 AND A/C OF BHAVESHBHAI JERAMBHA HAS BEEN CREDITED (IMPS REF NO 821213170309).'
# ACCOUNT NO XXXXXXXX5287
# DEBIT AMOUNT RS.15000.00
# DATE OF TRANSACTION 31-07-18
# TXN INSTRUMENT IMPS
# REFERENCE NO 821213170309
#
# Entities in 'HELLO! YOUR A/C NO. 885287 HAS BEEN DEBITED BY RS. 15005.9 ON 31JUL18. THE A/C BALANCE IS RS. 1336.00. INFO: IMPS/P2A/821213178702/0290104000225298IB. CALL 18605005555 (IF IN INDIA) IF YOU HAVE NOT DONE THIS TRANSACTION.'
# ACCOUNT NO 885287
# DEBIT AMOUNT RS. 15005.9
# DATE OF TRANSACTION 31JUL18
# ACCOUNT BALANCE RS. 1336.00
# TXN INSTRUMENT IMPS
#
# Entities in 'HELLO! YOUR A/C NO. 885287 HAS BEEN DEBITED BY RS. 150 ON 01AUG18. THE A/C BALANCE IS RS. 686.00. INFO: UPI/P2M/821310344069/PAYTM. CALL 18605005555 (IF IN INDIA) IF YOU HAVE NOT DONE THIS TRANSACTION.'
# ACCOUNT NO 885287
# DEBIT AMOUNT RS. 150
# DATE OF TRANSACTION 01AUG18
# ACCOUNT BALANCE RS. 686.00
#
# Entities in 'HELLO! YOUR A/C NO. 885287 HAS BEEN DEBITED BY RS. 6705.9 ON 07AUG18. THE A/C BALANCE IS RS. 3354.10. INFO: IMPS/P2A/821918676895/0290104000225298IB. CALL 18605005555 (IF IN INDIA) IF YOU HAVE NOT DONE THIS TRANSACTION.'
# ACCOUNT NO 885287
# DEBIT AMOUNT RS. 6705.9
# DATE OF TRANSACTION 07AUG18
# ACCOUNT BALANCE RS. 3354.10
# TXN INSTRUMENT IMPS
#
# Entities in 'YOUR A/C NO. XXXXXXXX2707 IS DEBITED FOR RS.50.00 ON 03-08-18 (UPI REF NO 821516301813)'
# ACCOUNT NO XXXXXXXX2707
# DEBIT AMOUNT RS.50.00
# DATE OF TRANSACTION 03-08-18
# TXN INSTRUMENT UPI
# REFERENCE NO 821516301813
#
# Entities in 'RS.440.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-05-25:21:16:49 AT MS VIJAYA FOODS. AVL BAL - RS.2939.00, CURR O/S - RS.21061.00'
# DEBIT AMOUNT RS.440.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-05-25:21:16:49
# VENDOR LIST MS VIJAYA FOODS
# TOTAL BALANCE RS.2939.00
# CURRENT OUTSTANDING RS.21061.00
#
# Entities in 'RS.240.00 WAS SPENT ON UR HDFCBANK CREDIT CARD ENDING 6922 ON 2018-05-27:21:49:05 AT PHONEPE. AVL BAL - RS.1979.00, CURR O/S - RS.22021.00'
# DEBIT AMOUNT RS.240.00
# TXN INSTRUMENT CREDIT CARD
# CARD NO 6922
# DATE OF TRANSACTION 2018-05-27:21:49:05
# VENDOR LIST PHONEPE
# TOTAL BALANCE RS.1979.00
# CURRENT OUTSTANDING RS.22021.00

# %%
df.to_csv("C:/Users/Simrandeep/Desktop/test/batch1_22jan_output.csv")
